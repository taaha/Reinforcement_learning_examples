# %% [markdown]
# ### Importing Dependencies

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# ### Test Environment

# %%
env = gym.make("CarRacing-v2", domain_randomize=False, render_mode="human")

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, trunc, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()

# %%
env.close()

# %% [markdown]
# ### Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
from stable_baselines3.common.env_util import make_vec_env

vec_env = make_vec_env("CarRacing-v0", n_envs=1)

# %%
model = PPO("CnnPolicy", vec_env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
# !pip install pyglet==1.5.27
# Out:
# Collecting pyglet==1.5.27
#   Downloading pyglet-1.5.27-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 468.1 kB/s eta 0:00:0000:0100:01
# Installing collected packages: pyglet
#   Attempting uninstall: pyglet
#     Found existing installation: pyglet 2.0.7
#     Uninstalling pyglet-2.0.7:
#       Successfully uninstalled pyglet-2.0.7
# Successfully installed pyglet-1.5.27

# %%
model.learn(total_timesteps=428000)
# Out:
# Track generation: 1131..1418 -> 287-tiles track
# Logging to Training/Logs/PPO_10
# Track generation: 1111..1399 -> 288-tiles track
# Track generation: 1078..1357 -> 279-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -58.1    |
# | time/              |          |
# |    fps             | 129      |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1198..1512 -> 314-tiles track
# Track generation: 1116..1399 -> 283-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -57.8       |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 2           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010591518 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -0.00217    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.281       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00935    |
# |    std                  | 0.99        |
# |    value_loss           | 0.612       |
# -----------------------------------------
# Track generation: 1088..1367 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1115..1397 -> 282-tiles track
# Track generation: 996..1250 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1125..1410 -> 285-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -57.6       |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 3           |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006718546 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.0589      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.248       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00566    |
# |    std                  | 0.976       |
# |    value_loss           | 0.602       |
# -----------------------------------------
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53         |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 4           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009515103 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.129       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.96        |
# |    value_loss           | 0.404       |
# -----------------------------------------
# Track generation: 1249..1566 -> 317-tiles track
# Track generation: 1062..1332 -> 270-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -52.5        |
# | time/                   |              |
# |    fps                  | 70           |
# |    iterations           | 5            |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0077683725 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | 0.246        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.108        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 0.952        |
# |    value_loss           | 0.45         |
# ------------------------------------------
# Track generation: 1343..1683 -> 340-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52         |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 6           |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015417109 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.944       |
# |    value_loss           | 0.365       |
# -----------------------------------------
# Track generation: 1050..1317 -> 267-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -50.1      |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 7          |
# |    time_elapsed         | 209        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01596872 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.07      |
# |    explained_variance   | 0.319      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0591     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0225    |
# |    std                  | 0.933      |
# |    value_loss           | 0.347      |
# ----------------------------------------
# Track generation: 1032..1296 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1077..1352 -> 275-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1011..1275 -> 264-tiles track
# Track generation: 1295..1623 -> 328-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.8       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 8           |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018229594 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0311      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0282     |
# |    std                  | 0.917       |
# |    value_loss           | 0.381       |
# -----------------------------------------
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.5       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 9           |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015216572 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0693      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.909       |
# |    value_loss           | 0.389       |
# -----------------------------------------
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1019..1278 -> 259-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 10          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017339453 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00334    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0256     |
# |    std                  | 0.896       |
# |    value_loss           | 0.245       |
# -----------------------------------------
# Track generation: 1027..1288 -> 261-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.6       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 11          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017186817 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0407      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0263     |
# |    std                  | 0.882       |
# |    value_loss           | 0.261       |
# -----------------------------------------
# Track generation: 1142..1432 -> 290-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.4       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 12          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.020111892 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 0.868       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# Track generation: 1128..1413 -> 285-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -49.2     |
# | time/                   |           |
# |    fps                  | 67        |
# |    iterations           | 13        |
# |    time_elapsed         | 394       |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0212707 |
# |    clip_fraction        | 0.211     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.82     |
# |    explained_variance   | 0.803     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00312  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -0.0332   |
# |    std                  | 0.861     |
# |    value_loss           | 0.21      |
# ---------------------------------------
# Track generation: 1070..1341 -> 271-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.6       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 14          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.024300009 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00728    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0315     |
# |    std                  | 0.846       |
# |    value_loss           | 0.231       |
# -----------------------------------------
# Track generation: 1210..1519 -> 309-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.3       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 15          |
# |    time_elapsed         | 453         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.026828475 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0317     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0311     |
# |    std                  | 0.83        |
# |    value_loss           | 0.172       |
# -----------------------------------------
# Track generation: 994..1256 -> 262-tiles track
# Track generation: 1057..1332 -> 275-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -49.4      |
# | time/                   |            |
# |    fps                  | 67         |
# |    iterations           | 16         |
# |    time_elapsed         | 482        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02359518 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.69      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0144    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0283    |
# |    std                  | 0.826      |
# |    value_loss           | 0.131      |
# ----------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.8       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 17          |
# |    time_elapsed         | 512         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.023471722 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0347      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0238     |
# |    std                  | 0.824       |
# |    value_loss           | 0.283       |
# -----------------------------------------
# Track generation: 1108..1389 -> 281-tiles track
# Track generation: 978..1227 -> 249-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.2       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 18          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.030912247 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0698     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0402     |
# |    std                  | 0.819       |
# |    value_loss           | 0.129       |
# -----------------------------------------
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1029..1296 -> 267-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47         |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 19          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.026129985 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0414      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0332     |
# |    std                  | 0.812       |
# |    value_loss           | 0.229       |
# -----------------------------------------
# Track generation: 1032..1294 -> 262-tiles track
# Track generation: 1103..1383 -> 280-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.3       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 20          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.039372515 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0422     |
# |    std                  | 0.802       |
# |    value_loss           | 0.333       |
# -----------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1046..1312 -> 266-tiles track
# Track generation: 1205..1514 -> 309-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1060..1329 -> 269-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -43        |
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 21         |
# |    time_elapsed         | 631        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.03267941 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.072      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0342    |
# |    std                  | 0.792      |
# |    value_loss           | 0.366      |
# ----------------------------------------
# Track generation: 1131..1424 -> 293-tiles track
# Track generation: 1071..1343 -> 272-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 22          |
# |    time_elapsed         | 660         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.036126334 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0329     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0301     |
# |    std                  | 0.778       |
# |    value_loss           | 0.306       |
# -----------------------------------------
# Track generation: 1071..1347 -> 276-tiles track
# Track generation: 1035..1300 -> 265-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 903..1139 -> 236-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -38.8       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 23          |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.044102117 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.01        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.762       |
# |    value_loss           | 0.545       |
# -----------------------------------------
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -36.5       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 24          |
# |    time_elapsed         | 720         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.054656558 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0294     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0397     |
# |    std                  | 0.753       |
# |    value_loss           | 0.374       |
# -----------------------------------------
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -32.5       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 25          |
# |    time_elapsed         | 750         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.045634218 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0199      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0286     |
# |    std                  | 0.742       |
# |    value_loss           | 0.564       |
# -----------------------------------------
# Track generation: 1277..1600 -> 323-tiles track
# Track generation: 1206..1512 -> 306-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -27.5       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 26          |
# |    time_elapsed         | 786         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.027954828 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.206       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.737       |
# |    value_loss           | 0.746       |
# -----------------------------------------
# Track generation: 1140..1433 -> 293-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1345..1685 -> 340-tiles track
# Track generation: 1291..1618 -> 327-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -23.6       |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 27          |
# |    time_elapsed         | 846         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.052418686 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0857      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.733       |
# |    value_loss           | 1.3         |
# -----------------------------------------
# Track generation: 1286..1612 -> 326-tiles track
# Track generation: 1137..1425 -> 288-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -21        |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 28         |
# |    time_elapsed         | 897        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.07362477 |
# |    clip_fraction        | 0.33       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.29      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0844     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0236    |
# |    std                  | 0.721      |
# |    value_loss           | 0.807      |
# ----------------------------------------
# Track generation: 1015..1273 -> 258-tiles track
# Track generation: 1263..1583 -> 320-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14.7       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 29          |
# |    time_elapsed         | 954         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.039580975 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0817      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0268     |
# |    std                  | 0.718       |
# |    value_loss           | 0.602       |
# -----------------------------------------
# Track generation: 1117..1400 -> 283-tiles track
# Track generation: 1030..1293 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1070..1348 -> 278-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.78       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 30          |
# |    time_elapsed         | 1015        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.034960076 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.316       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0228     |
# |    std                  | 0.713       |
# |    value_loss           | 1.46        |
# -----------------------------------------
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.45       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 31          |
# |    time_elapsed         | 1070        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.035234265 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.188       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00903    |
# |    std                  | 0.704       |
# |    value_loss           | 1.36        |
# -----------------------------------------
# Track generation: 946..1190 -> 244-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1235..1548 -> 313-tiles track
# Track generation: 1158..1458 -> 300-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 3.98        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 32          |
# |    time_elapsed         | 1119        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.038115017 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.209       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.705       |
# |    value_loss           | 1.66        |
# -----------------------------------------
# Track generation: 1033..1295 -> 262-tiles track
# Track generation: 1085..1367 -> 282-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 33          |
# |    time_elapsed         | 1164        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.040178977 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.204       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.7         |
# |    value_loss           | 1.81        |
# -----------------------------------------
# Track generation: 1006..1269 -> 263-tiles track
# Track generation: 1002..1263 -> 261-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 19.9       |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 34         |
# |    time_elapsed         | 1214       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.06734747 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.294      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00565   |
# |    std                  | 0.698      |
# |    value_loss           | 2.83       |
# ----------------------------------------
# Track generation: 1234..1547 -> 313-tiles track
# Track generation: 1256..1574 -> 318-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 27.1      |
# | time/                   |           |
# |    fps                  | 56        |
# |    iterations           | 35        |
# |    time_elapsed         | 1260      |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0457315 |
# |    clip_fraction        | 0.37      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.15     |
# |    explained_variance   | 0.912     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.562     |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.0174   |
# |    std                  | 0.697     |
# |    value_loss           | 3.64      |
# ---------------------------------------
# Track generation: 1177..1475 -> 298-tiles track
# Track generation: 1293..1621 -> 328-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 34.7       |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 36         |
# |    time_elapsed         | 1319       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.06708558 |
# |    clip_fraction        | 0.435      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.845      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.06       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00274   |
# |    std                  | 0.695      |
# |    value_loss           | 7.66       |
# ----------------------------------------
# Track generation: 1237..1550 -> 313-tiles track
# Track generation: 1165..1460 -> 295-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 45.2        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 37          |
# |    time_elapsed         | 1380        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.082983606 |
# |    clip_fraction        | 0.471       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.959       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0036      |
# |    std                  | 0.693       |
# |    value_loss           | 2.87        |
# -----------------------------------------
# Track generation: 1006..1267 -> 261-tiles track
# Track generation: 1182..1482 -> 300-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 60.3       |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 38         |
# |    time_elapsed         | 1423       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.07739785 |
# |    clip_fraction        | 0.449      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.861      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.849      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00618   |
# |    std                  | 0.688      |
# |    value_loss           | 4.76       |
# ----------------------------------------
# Track generation: 1100..1379 -> 279-tiles track
# Track generation: 1368..1714 -> 346-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 69.5        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 39          |
# |    time_elapsed         | 1465        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.060601585 |
# |    clip_fraction        | 0.476       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.843       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00377     |
# |    std                  | 0.688       |
# |    value_loss           | 9.69        |
# -----------------------------------------
# Track generation: 1307..1638 -> 331-tiles track
# Track generation: 1260..1579 -> 319-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 72.9       |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 40         |
# |    time_elapsed         | 1500       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.09955089 |
# |    clip_fraction        | 0.482      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.11      |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.348      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00285    |
# |    std                  | 0.686      |
# |    value_loss           | 5.58       |
# ----------------------------------------
# Track generation: 1312..1644 -> 332-tiles track
# Track generation: 1117..1400 -> 283-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 79.3       |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 41         |
# |    time_elapsed         | 1534       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.08425165 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.974      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00505    |
# |    std                  | 0.684      |
# |    value_loss           | 9.68       |
# ----------------------------------------
# Track generation: 1137..1425 -> 288-tiles track
# Track generation: 1049..1322 -> 273-tiles track
# Track generation: 1049..1320 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1064..1334 -> 270-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 992        |
# |    ep_rew_mean          | 86         |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 42         |
# |    time_elapsed         | 1565       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.06652299 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.22       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.000194  |
# |    std                  | 0.685      |
# |    value_loss           | 5.89       |
# ----------------------------------------
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1246..1561 -> 315-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 993        |
# |    ep_rew_mean          | 88.7       |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 43         |
# |    time_elapsed         | 1596       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.35293493 |
# |    clip_fraction        | 0.595      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.927      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.0253     |
# |    std                  | 0.686      |
# |    value_loss           | 13.9       |
# ----------------------------------------
# Track generation: 1087..1363 -> 276-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 993        |
# |    ep_rew_mean          | 92.2       |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 44         |
# |    time_elapsed         | 1627       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.09939432 |
# |    clip_fraction        | 0.428      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.349      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.00466    |
# |    std                  | 0.681      |
# |    value_loss           | 3.47       |
# ----------------------------------------
# Track generation: 1223..1533 -> 310-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 993        |
# |    ep_rew_mean          | 91         |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 45         |
# |    time_elapsed         | 1659       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.10805931 |
# |    clip_fraction        | 0.433      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.45       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00302    |
# |    std                  | 0.682      |
# |    value_loss           | 8.06       |
# ----------------------------------------
# Track generation: 1175..1478 -> 303-tiles track
# Track generation: 1252..1569 -> 317-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 993        |
# |    ep_rew_mean          | 96.9       |
# | time/                   |            |
# |    fps                  | 55         |
# |    iterations           | 46         |
# |    time_elapsed         | 1690       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.09761522 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.223      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.00171    |
# |    std                  | 0.683      |
# |    value_loss           | 3.17       |
# ----------------------------------------
# Track generation: 1031..1293 -> 262-tiles track
# Track generation: 1139..1434 -> 295-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 993         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 47          |
# |    time_elapsed         | 1721        |
# ...
# |    ep_rew_mean          | 729        |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 194        |
# |    time_elapsed         | 6218       |
# |    total_timesteps      | 397312     |
# | train/                  |            |
# |    approx_kl            | 0.12708122 |
# |    clip_fraction        | 0.539      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.03      |
# |    explained_variance   | 0.884      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.14       |
# |    n_updates            | 1930       |
# |    policy_gradient_loss | 0.0277     |
# |    std                  | 0.67       |
# |    value_loss           | 10.7       |
# ----------------------------------------
# Track generation: 1117..1400 -> 283-tiles track
# Track generation: 1197..1500 -> 303-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 975        |
# |    ep_rew_mean          | 728        |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 195        |
# |    time_elapsed         | 6248       |
# |    total_timesteps      | 399360     |
# | train/                  |            |
# |    approx_kl            | 0.13800073 |
# |    clip_fraction        | 0.576      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.782      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.69       |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | 0.0349     |
# |    std                  | 0.677      |
# |    value_loss           | 14.1       |
# ----------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 949..1195 -> 246-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 975        |
# |    ep_rew_mean          | 726        |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 196        |
# |    time_elapsed         | 6278       |
# |    total_timesteps      | 401408     |
# | train/                  |            |
# |    approx_kl            | 0.13769752 |
# |    clip_fraction        | 0.533      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.05      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12       |
# |    n_updates            | 1950       |
# |    policy_gradient_loss | 0.0122     |
# |    std                  | 0.675      |
# |    value_loss           | 7.37       |
# ----------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1271..1593 -> 322-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 975        |
# |    ep_rew_mean          | 729        |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 197        |
# |    time_elapsed         | 6309       |
# |    total_timesteps      | 403456     |
# | train/                  |            |
# |    approx_kl            | 0.10508547 |
# |    clip_fraction        | 0.57       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.843      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.39       |
# |    n_updates            | 1960       |
# |    policy_gradient_loss | 0.0316     |
# |    std                  | 0.678      |
# |    value_loss           | 11.3       |
# ----------------------------------------
# Track generation: 1128..1420 -> 292-tiles track
# Track generation: 1245..1561 -> 316-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 976       |
# |    ep_rew_mean          | 724       |
# | time/                   |           |
# |    fps                  | 63        |
# |    iterations           | 198       |
# |    time_elapsed         | 6340      |
# |    total_timesteps      | 405504    |
# | train/                  |           |
# |    approx_kl            | 0.1400077 |
# |    clip_fraction        | 0.586     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.09     |
# |    explained_variance   | 0.933     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.84      |
# |    n_updates            | 1970      |
# |    policy_gradient_loss | 0.0131    |
# |    std                  | 0.689     |
# |    value_loss           | 8.14      |
# ---------------------------------------
# Track generation: 1251..1568 -> 317-tiles track
# Track generation: 1391..1744 -> 353-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 976        |
# |    ep_rew_mean          | 716        |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 199        |
# |    time_elapsed         | 6371       |
# |    total_timesteps      | 407552     |
# | train/                  |            |
# |    approx_kl            | 0.13772917 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.858      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.579      |
# |    n_updates            | 1980       |
# |    policy_gradient_loss | 0.0078     |
# |    std                  | 0.693      |
# |    value_loss           | 9.1        |
# ----------------------------------------
# Track generation: 1272..1593 -> 321-tiles track
# Track generation: 1145..1436 -> 291-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 976        |
# |    ep_rew_mean          | 711        |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 200        |
# |    time_elapsed         | 6402       |
# |    total_timesteps      | 409600     |
# | train/                  |            |
# |    approx_kl            | 0.10661082 |
# |    clip_fraction        | 0.574      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.77       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.683      |
# |    n_updates            | 1990       |
# |    policy_gradient_loss | -0.00257   |
# |    std                  | 0.696      |
# |    value_loss           | 4.3        |
# ----------------------------------------
# Track generation: 1127..1413 -> 286-tiles track
# Track generation: 1060..1336 -> 276-tiles track
# Track generation: 1222..1531 -> 309-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 976        |
# |    ep_rew_mean          | 708        |
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 201        |
# |    time_elapsed         | 6432       |
# |    total_timesteps      | 411648     |
# | train/                  |            |
# |    approx_kl            | 0.21058744 |
# |    clip_fraction        | 0.577      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.57       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.566      |
# |    n_updates            | 2000       |
# |    policy_gradient_loss | 0.0181     |
# |    std                  | 0.696      |
# |    value_loss           | 3.52       |
# ----------------------------------------
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1317..1650 -> 333-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 976         |
# |    ep_rew_mean          | 704         |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 202         |
# |    time_elapsed         | 6463        |
# |    total_timesteps      | 413696      |
# | train/                  |             |
# |    approx_kl            | 0.110080585 |
# |    clip_fraction        | 0.578       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.658       |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | 0.0181      |
# |    std                  | 0.706       |
# |    value_loss           | 3.05        |
# -----------------------------------------
# Track generation: 1175..1472 -> 297-tiles track
# Track generation: 994..1248 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1103..1383 -> 280-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 976        |
# |    ep_rew_mean          | 701        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 203        |
# |    time_elapsed         | 6495       |
# |    total_timesteps      | 415744     |
# | train/                  |            |
# |    approx_kl            | 0.09706743 |
# |    clip_fraction        | 0.501      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.55       |
# |    n_updates            | 2020       |
# |    policy_gradient_loss | -0.000494  |
# |    std                  | 0.706      |
# |    value_loss           | 4.79       |
# ----------------------------------------
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 1077..1356 -> 279-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 976        |
# |    ep_rew_mean          | 707        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 204        |
# |    time_elapsed         | 6525       |
# |    total_timesteps      | 417792     |
# | train/                  |            |
# |    approx_kl            | 0.10531624 |
# |    clip_fraction        | 0.514      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.779      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.4        |
# |    n_updates            | 2030       |
# |    policy_gradient_loss | 0.00225    |
# |    std                  | 0.709      |
# |    value_loss           | 4.5        |
# ----------------------------------------
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1022..1286 -> 264-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 977        |
# |    ep_rew_mean          | 701        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 205        |
# |    time_elapsed         | 6556       |
# |    total_timesteps      | 419840     |
# | train/                  |            |
# |    approx_kl            | 0.10169957 |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.794      |
# |    n_updates            | 2040       |
# |    policy_gradient_loss | 0.00162    |
# |    std                  | 0.712      |
# |    value_loss           | 3.72       |
# ----------------------------------------
# Track generation: 1216..1524 -> 308-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | 698         |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 206         |
# |    time_elapsed         | 6587        |
# |    total_timesteps      | 421888      |
# | train/                  |             |
# |    approx_kl            | 0.060841568 |
# |    clip_fraction        | 0.491       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.5         |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | 0.0101      |
# |    std                  | 0.714       |
# |    value_loss           | 6.02        |
# -----------------------------------------
# Track generation: 1312..1644 -> 332-tiles track
# Track generation: 1310..1642 -> 332-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 977        |
# |    ep_rew_mean          | 695        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 207        |
# |    time_elapsed         | 6618       |
# |    total_timesteps      | 423936     |
# | train/                  |            |
# |    approx_kl            | 0.08738151 |
# |    clip_fraction        | 0.499      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.306      |
# |    n_updates            | 2060       |
# |    policy_gradient_loss | -0.00747   |
# |    std                  | 0.71       |
# |    value_loss           | 3.51       |
# ----------------------------------------
# Track generation: 1182..1482 -> 300-tiles track
# Track generation: 1145..1435 -> 290-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 977        |
# |    ep_rew_mean          | 691        |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 208        |
# |    time_elapsed         | 6650       |
# |    total_timesteps      | 425984     |
# | train/                  |            |
# |    approx_kl            | 0.09284408 |
# |    clip_fraction        | 0.446      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.708      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.606      |
# |    n_updates            | 2070       |
# |    policy_gradient_loss | -0.00811   |
# |    std                  | 0.71       |
# |    value_loss           | 3.54       |
# ----------------------------------------
# Track generation: 1137..1433 -> 296-tiles track
# Track generation: 1076..1357 -> 281-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | 689         |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 209         |
# |    time_elapsed         | 6681        |
# |    total_timesteps      | 428032      |
# | train/                  |             |
# |    approx_kl            | 0.093723886 |
# |    clip_fraction        | 0.519       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.64        |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | -0.00133    |
# |    std                  | 0.711       |
# |    value_loss           | 3.18        |
# -----------------------------------------

# %% [markdown]
# ### Saving Model

# %%
ppo_path = os.path.join('Training', 'Saved_Models', 'PPO_428k_Driving_model')

# %%
model.save(ppo_path)

# %% [markdown]
# ### Evaluate and Test

# %%
evaluate_policy(model, vec_env, n_eval_episodes=1, render=True)
env.close()

# %%
import imageio
import numpy as np

env = make_vec_env("CarRacing-v0", n_envs=1)
images = []
obs = env.reset()
img = env.render(mode="rgb_array")
for _ in range(500):
    images.append(img)
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    img = env.render(mode="rgb_array")
    # env.render()

env.close()
imageio.mimsave("self_driving_car_trained_agent_428k_steps.gif", [np.array(img) for i, img in enumerate(images) if i%2 == 0], duration=40)
# Out:
# Track generation: 1314..1647 -> 333-tiles track
