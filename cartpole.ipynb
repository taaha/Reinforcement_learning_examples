# %% [markdown]
# ### Importing dependencies

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ### Loading Environment

# %%
env = gym.make('CartPole-v1', render_mode="human")

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, trunc, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:38.0
# Episode:2 Score:22.0
# Episode:3 Score:9.0
# Episode:4 Score:13.0
# Episode:5 Score:24.0

# %% [markdown]
# ### Train RL model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
from stable_baselines3.common.env_util import make_vec_env

vec_env = make_vec_env("CartPole-v1", n_envs=1)
model = PPO("MlpPolicy", vec_env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=25000)
# Out:
# Logging to Training/Logs/PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | 24.8     |
# | time/              |          |
# |    fps             | 1539     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 30          |
# | time/                   |             |
# |    fps                  | 1000        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009105258 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00424    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 63          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.9        |
# |    ep_rew_mean          | 36.9        |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009055836 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0497      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 39          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.9        |
# |    ep_rew_mean          | 47.9        |
# | time/                   |             |
# |    fps                  | 899         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009426577 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 52          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | 62.1        |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009418574 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 62.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.5         |
# |    ep_rew_mean          | 79.5         |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0068649626 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.599       |
# |    explained_variance   | 0.458        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.8         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00955     |
# |    value_loss           | 64.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93          |
# |    ep_rew_mean          | 93          |
# | time/                   |             |
# |    fps                  | 699         |
# |    iterations           | 7           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007933525 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 56.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005063319 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 50.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 670          |
# |    iterations           | 9            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0060054157 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.309        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00608     |
# |    value_loss           | 45.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 151          |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 676          |
# |    iterations           | 10           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0035150053 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 16.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 168        |
# |    ep_rew_mean          | 168        |
# | time/                   |            |
# |    fps                  | 659        |
# |    iterations           | 11         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00567188 |
# |    clip_fraction        | 0.0386     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.552     |
# |    explained_variance   | 0.572      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.5       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00593   |
# |    value_loss           | 58         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 187          |
# |    ep_rew_mean          | 187          |
# | time/                   |              |
# |    fps                  | 652          |
# |    iterations           | 12           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0125614945 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.433        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 7.33         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 649         |
# |    iterations           | 13          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008813307 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.564       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 4.31        |
# -----------------------------------------

# %% [markdown]
# ### Save and Reload Model

# %%
PPO_path = os.path.join('Training', 'Saved_Models', 'PPO_model')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path)

# %% [markdown]
# ### Evaluation

# %%
evaluate_policy(model, vec_env, n_eval_episodes=10, render=False)
# Out:
# (500.0, 0.0)

# %%
env.close()

# %% [markdown]
# ### Model Testing

# %%
env = gym.make('CartPole-v1', render_mode="human")
obs = env.reset()[0]
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, trunc, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info {}

# %%
env.close()

# %% [markdown]
# ### See logs in tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_4')

# %%
# !tensorboard --logdir={training_log_path}

# %% [markdown]
# ### Using Callback

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved_Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make('CartPole-v1', render_mode="human")
vec_env = make_vec_env("CartPole-v1", n_envs=1)

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(vec_env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO("MlpPolicy", vec_env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_8
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | 19.8     |
# | time/              |          |
# |    fps             | 1366     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 26.2        |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008539352 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.000284    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.77        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 44.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35          |
# |    ep_rew_mean          | 35          |
# | time/                   |             |
# |    fps                  | 667         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008591711 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.0866      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.91        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 33.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.4        |
# |    ep_rew_mean          | 46.4        |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008938082 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 54.5        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=383.20 +/- 96.25
# Episode length: 383.20 +/- 96.25
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 383         |
# |    mean_reward          | 383         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.009128513 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 67          |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 383.20  is above the threshold 190

# %%
evaluate_policy(model, vec_env, n_eval_episodes=10, render=False)
# Out:
# (440.0, 92.22038820130828)

# %%
env.close()

# %% [markdown]
# ### Using custom neural network architecture

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', vec_env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | 21.8     |
# | time/              |          |
# |    fps             | 821      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 29.6        |
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015071506 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.00428     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.48        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 18.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | 42.2        |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014822905 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0339     |
# |    value_loss           | 30.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.5        |
# |    ep_rew_mean          | 57.5        |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013731083 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0302     |
# |    value_loss           | 48.6        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=307.60 +/- 46.78
# Episode length: 307.60 +/- 46.78
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 308        |
# |    mean_reward          | 308        |
# | time/                   |            |
# |    total_timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.01160438 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.564     |
# |    explained_variance   | 0.465      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.3       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0198    |
# |    value_loss           | 46.4       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.6     |
# |    ep_rew_mean     | 74.6     |
# | time/              |          |
# |    fps             | 271      |
# |    iterations      | 5        |
# |    time_elapsed    | 37       |
# |    total_timesteps | 10240    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.5        |
# |    ep_rew_mean          | 90.5        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 6           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018688306 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.2         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 17.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 7           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022342863 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.517      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 8.93        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 127          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 8            |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0097922385 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.456        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00606     |
# |    value_loss           | 7.19         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 9           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010341033 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.486      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.00176     |
# |    value_loss           | 4.35        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | 500          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0058147153 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.133        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.00028      |
# |    value_loss           | 2.92         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 190

# %%
evaluate_policy(model, vec_env, n_eval_episodes=10, render=False)
# Out:
# (500.0, 0.0)

# %% [markdown]
# ### Using Alternate Algorithms

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', vec_env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.8     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6577     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 99       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 6898     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 190      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7382     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 276      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.7     |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 7692     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 379      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.6     |
# |    ep_rew_mean      | 23.6     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 7920     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 471      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.2     |
# |    ep_rew_mean      | 24.2     |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 8178     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 581      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.8     |
# |    ep_rew_mean      | 23.8     |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 8231     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 666      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 8277     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 749      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 7784     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 819      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7591     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 902      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 6723     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 975      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 6550     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 6326     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 6193     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 6264     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5844     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1364     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.307    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5873     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1458     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5945     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.234    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 6023     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.203    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 6066     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1677     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.168    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 6149     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1752     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.137    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 6204     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.0999   |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 6281     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.0671   |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 6337     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6449     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 6520     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 6622     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2268     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 6707     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 6796     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 6834     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 6873     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 6941     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 6971     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2770     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 6996     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 7037     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 7105     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 7136     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 7165     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 7206     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 7252     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3321     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 7302     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 7364     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 7387     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 7420     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 7427     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 7455     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 7450     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 7473     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3985     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 7498     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 7528     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 7551     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 7551     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4291     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 7577     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 7582     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 7635     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4571     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 7653     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 7690     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 7699     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4851     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 7714     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 7726     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 7749     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5090     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 7776     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 7789     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 7796     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 7817     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 7831     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 7884     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 7893     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 7903     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 7923     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 7935     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 7982     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 7994     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 8018     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 8014     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 8024     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 8031     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 8030     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 8038     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 8041     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 8064     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 8065     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 8074     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 8087     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 8098     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7226     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 8118     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 8124     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 8114     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 8112     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 8121     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 8130     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7690     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 8138     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7785     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 8143     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7850     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 8157     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 8176     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 8196     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 8193     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 8199     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8314     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 8206     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 8220     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 8222     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 8227     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 8230     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 8230     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 8235     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 8238     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 8239     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 8250     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 8248     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 8260     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 8260     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 8276     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 8285     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 8288     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 8294     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 8300     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9763     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 8302     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 8306     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9904     |
# ----------------------------------
# Eval num_timesteps=10000, episode_reward=9.00 +/- 0.63
# Episode length: 9.00 +/- 0.63
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9        |
# |    mean_reward      | 9        |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 10000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 7153     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 7077     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 7028     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 6992     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 6963     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# ...
# |    episodes         | 768      |
# |    fps              | 7455     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 7458     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 7464     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 7476     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 7486     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 7490     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 7500     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 7506     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 7512     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 7516     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 7528     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 7531     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 7537     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 7540     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 7543     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 7544     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 7555     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 17938    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 7561     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 7573     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 7577     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 7580     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 7583     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 7589     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 7593     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 7598     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 7603     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 7610     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 7616     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 7620     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 18956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 7621     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19038    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 7624     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 7620     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 7616     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 7620     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 7623     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 7618     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 7627     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 7644     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 7653     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 7654     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 7657     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19988    |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=9.00 +/- 0.00
# Episode length: 9.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9        |
# |    mean_reward      | 9        |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 20000    |
# ----------------------------------

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
evaluate_policy(model, vec_env, n_eval_episodes=10)
# Out:
# (9.5, 0.6708203932499369)

# %%
env.close()
